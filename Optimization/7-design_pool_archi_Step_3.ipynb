# %% [markdown]
# #### Design Pool generation for architecture related features (Step-3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import pickle

# %%
pwd = os.getcwd() # current wroking directory

# %%
df = pd.read_csv(pwd+"/Sn_based/Sn_cleaned.csv") # loading Sn based dataset
df.head()
# Out:
#                   Ref_DOI_number Cell_architecture  Cell_flexible  \
# 0         10.1002/adfm.201807696               pin          False
# 1         10.1002/adfm.201807696               pin          False
# 2         10.1002/adfm.201807696               pin          False
# 3         10.1002/adfm.201807696               pin          False
# 4  10.1021/acsenergylett.9b00954               pin          False
#
#    Cell_semitransparent Substrate_stack_sequence ETL_stack_sequence  \
# 0                 False                SLG | ITO      PCBM-60 | BCP
# 1                 False                SLG | ITO      PCBM-60 | BCP
# 2                 False                SLG | ITO      PCBM-60 | BCP
# 3                 False                SLG | ITO      PCBM-60 | BCP
# 4                 False                SLG | ITO          C60 | LiF
#
#    ETL_thickness    ETL_deposition_procedure  Perovskite_dimension_2D  \
# 0          142.0  Spin-coating | Evaporation                     True
# 1          142.0  Spin-coating | Evaporation                     True
# 2          142.0  Spin-coating | Evaporation                     True
# 3          142.0  Spin-coating | Evaporation                     True
# 4           31.0   Evaporation | Evaporation                     True
#
#    Perovskite_dimension_2D3D_mixture  ...  HTL_stack_sequence  \
# 0                              False  ...           PEDOT:PSS
# 1                              False  ...           PEDOT:PSS
# 2                              False  ...           PEDOT:PSS
# 3                              False  ...           PEDOT:PSS
# 4                              False  ...           PEDOT:PSS
#
#    HTL_thickness_list  HTL_deposition_procedure Backcontact_stack_sequence  \
# 0               114.0              Spin-coating                         Ag
# 1               114.0              Spin-coating                         Ag
# 2               114.0              Spin-coating                         Ag
# 3               114.0              Spin-coating                         Ag
# 4                38.0              Spin-coating                         Al
#
#    Backcontact_thickness_list  Backcontact_deposition_procedure  \
# 0                       200.0                       Evaporation
# 1                       200.0                       Evaporation
# 2                       200.0                       Evaporation
# 3                       200.0                       Evaporation
# 4                       100.0                       Evaporation
#
#    JV_default_Voc  JV_default_Jsc JV_default_FF JV_default_PCE
# 0            0.58            21.2         0.633           7.78
# 1            0.60            20.5         0.650           7.95
# 2            0.61            21.0         0.670           8.71
# 3            0.54            20.3         0.630           5.94
# 4            0.56            18.3         0.493           5.07
#
# [5 rows x 34 columns]

# %%
df.shape # shape of the Sn-based dataset
# Out:
# (256, 34)

# %%
# selected columns
cols = ['Cell_architecture', 'Cell_flexible',
       'Cell_semitransparent', 'Substrate_stack_sequence',
       'ETL_stack_sequence', 'ETL_thickness', 'ETL_deposition_procedure',
       'Perovskite_dimension_2D', 'Perovskite_dimension_2D3D_mixture',
       'Perovskite_dimension_3D',
       'Perovskite_dimension_3D_with_2D_capping_layer',
       'Perovskite_composition_perovskite_ABC3_structure',
       'Perovskite_composition_long_form',
       'Perovskite_thickness',
       'Perovskite_composition_inorganic', 'Perovskite_band_gap',
       'Perovskite_band_gap_graded', 'Perovskite_deposition_procedure',
       'Perovskite_deposition_solvents',
       'Perovskite_deposition_quenching_induced_crystallisation',
       'Perovskite_deposition_thermal_annealing_temperature',
       'Perovskite_deposition_thermal_annealing_time',
       'Perovskite_deposition_solvent_annealing', 'HTL_stack_sequence',
       'HTL_thickness_list', 'HTL_deposition_procedure',
       'Backcontact_stack_sequence', 'Backcontact_thickness_list',
       'Backcontact_deposition_procedure', 'JV_default_PCE']
df = df[cols]
df.shape
# Out:
# (256, 30)

# %%
feats = df.iloc[:,:-1] # selecting features
feats.shape # shape of the feature data
# Out:
# (256, 29)

# %%
numerical = list(feats.select_dtypes(include="float64")) # numerical features
categorical = list(feats.select_dtypes(include="object")) # categorical features
boolean = list(feats.select_dtypes(include="bool")) # boolean featuers

print("Numerical: ", len(numerical))
print("Categorical: ", len(categorical))
print("Boolean: ", len(boolean))
# Out:
# Numerical:  5
# Categorical:  13
# Boolean:  11

# %%
# architecture related features
feats_arch = [        
            'Cell_architecture', 'Cell_flexible',
            'Cell_semitransparent', 'Substrate_stack_sequence',
            'ETL_stack_sequence',
            'ETL_thickness', 
            'Perovskite_dimension_2D', 'Perovskite_dimension_2D3D_mixture',
            'Perovskite_dimension_3D',
            'Perovskite_dimension_3D_with_2D_capping_layer',
            'Perovskite_composition_perovskite_ABC3_structure',
            'Perovskite_composition_long_form',
            'Perovskite_composition_inorganic',
            'Perovskite_thickness',
            'Perovskite_band_gap', 'Perovskite_band_gap_graded',
            'HTL_stack_sequence',
            'HTL_thickness_list',
            'Backcontact_stack_sequence',
            'Backcontact_thickness_list']
# deposition related features
feats_deposition = [
            'ETL_deposition_procedure',
            'Perovskite_deposition_procedure', 
            'Perovskite_deposition_solvents',
            'Perovskite_deposition_quenching_induced_crystallisation',
            'Perovskite_deposition_thermal_annealing_temperature',
            'Perovskite_deposition_thermal_annealing_time',
            'Perovskite_deposition_solvent_annealing',
            'HTL_deposition_procedure',
            'Backcontact_deposition_procedure'
]
# printing number of features in each group
print(f"Architecture features: {len(feats_arch)}\nDeposition features: {len(feats_deposition)}\nTotal features: {feats.shape[1]}")
# Out:
# Architecture features: 20
# Deposition features: 9
# Total features: 29

# %%
# Number of unique labels on each feature related to device architecture
archi_unique = {}
for f in feats_arch:
    lst = list(df[f].unique())
    archi_unique[f] = lst
for k in archi_unique.keys():
    print(k+" : "+str(len(archi_unique[k])))
# Out:
# Cell_architecture : 2
# Cell_flexible : 1
# Cell_semitransparent : 1
# Substrate_stack_sequence : 2
# ETL_stack_sequence : 19
# ETL_thickness : 64
# Perovskite_dimension_2D : 2
# Perovskite_dimension_2D3D_mixture : 2
# Perovskite_dimension_3D : 2
# Perovskite_dimension_3D_with_2D_capping_layer : 1
# Perovskite_composition_perovskite_ABC3_structure : 2
# Perovskite_composition_long_form : 80
# Perovskite_composition_inorganic : 2
# Perovskite_thickness : 55
# Perovskite_band_gap : 45
# Perovskite_band_gap_graded : 1
# HTL_stack_sequence : 20
# HTL_thickness_list : 69
# Backcontact_stack_sequence : 7
# Backcontact_thickness_list : 18

# %% [markdown]
# ### Design pool for architecture related features

# %%
"""feats_arch = [        
                  'Cell_architecture',   
                  'Cell_flexible',       
                  'Cell_semitransparent', 
                  'Substrate_stack_sequence',
                  'ETL_stack_sequence',
                  'ETL_thickness', 
                  'Perovskite_dimension_2D',  
                  'Perovskite_dimension_2D3D_mixture',
                  'Perovskite_dimension_3D', 
                  'Perovskite_dimension_3D_with_2D_capping_layer', 
                  'Perovskite_composition_perovskite_ABC3_structure', 
                  'Perovskite_composition_long_form', 
                  'Perovskite_composition_inorganic', 
                  'Perovskite_thickness', 
                  'Perovskite_band_gap', 
                  'Perovskite_band_gap_graded', 
                  'HTL_stack_sequence', 
                  'HTL_thickness_list', 
                  'Backcontact_stack_sequence', 
                  'Backcontact_thickness_list'
                ]
"""
# Making a list of unique labels in each column
cell_arch_lst = archi_unique['Cell_architecture']
cell_flex_lst = archi_unique['Cell_flexible']
cell_semi_lst = archi_unique['Cell_semitransparent']
subs_lst = archi_unique['Substrate_stack_sequence']
etl_lst = archi_unique['ETL_stack_sequence']
# etl_th_lst = []
per_2d_lst = archi_unique['Perovskite_dimension_2D']
per_2d3d_lst = archi_unique['Perovskite_dimension_2D3D_mixture']
per_3d_lst = archi_unique['Perovskite_dimension_3D']
per_3d2d_cap_lst = archi_unique['Perovskite_dimension_3D_with_2D_capping_layer'] 
per_abc3_lst = archi_unique['Perovskite_composition_perovskite_ABC3_structure']
per_lst = archi_unique['Perovskite_composition_long_form']
per_ino_lst = archi_unique['Perovskite_composition_inorganic']
# per_th_lst = []
# per_band_lst = []
per_band_grad_lst = archi_unique['Perovskite_band_gap_graded']
htl_lst = archi_unique['HTL_stack_sequence']
# htl_th_lst = []
back_lst = archi_unique['Backcontact_stack_sequence']
# back_th = []

cell_arch = []
cell_flex = []
cell_semi = []
subs = []
etl = [] 
# etl_th_lst = [26.0]
per_2d = []
per_2d3d = []
per_3d = []
per_3d2d_cap = []
per_abc3 = []
per = []
per_ino = []
# per_th_lst = [350.0]
# per_band_lst = [1.6]
per_band_grad = []
htl = [] 
# htl_th_lst = [344.0]
back = []
# back_th = [100.0]

# Permutating through each layers of features
for l0 in cell_arch_lst:
    for l1 in cell_flex_lst:
        for l2 in cell_semi_lst:
            for l3 in subs_lst:
                for l4 in etl_lst:
                    for l5 in per_2d_lst:
                        for l6 in per_2d3d_lst:
                            for l7 in per_3d_lst:
                                for l8 in per_3d2d_cap_lst:
                                    for l9 in per_abc3_lst:
                                        for l10 in per_lst:
                                            for l11 in per_ino_lst:
                                                for l12 in per_band_grad_lst:
                                                    for l13 in htl_lst:
                                                        for l14 in back_lst:
                                                            cell_arch.append(l0)
                                                            cell_flex.append(l1)
                                                            cell_semi.append(l2)
                                                            subs.append(l3)
                                                            etl.append(l4)
                                                            per_2d.append(l5)
                                                            per_2d3d.append(l6)
                                                            per_3d.append(l7)
                                                            per_3d2d_cap.append(l8)
                                                            per_abc3.append(l9)
                                                            per.append(l10)
                                                            per_ino.append(l11)
                                                            per_band_grad.append(l12)
                                                            htl.append(l13)
                                                            back.append(l14)

# Create a design pool of all possible combination of arcthitecture related features                                                         
dp_archi = pd.DataFrame(
{   'Cell_architecture': cell_arch,
    'Cell_flexible': cell_flex,
    'Cell_semitransparent': cell_semi,
    'Substrate_stack_sequence': subs,
    'ETL_stack_sequence': etl,
    'Perovskite_dimension_2D': per_2d,
    'Perovskite_dimension_2D3D_mixture': per_2d3d,
    'Perovskite_dimension_3D': per_3d,
    'Perovskite_dimension_3D_with_2D_capping_layer': per_3d2d_cap,
    'Perovskite_composition_perovskite_ABC3_structure': per_abc3,
    'Perovskite_composition_long_form': per,
    'Perovskite_composition_inorganic': per_ino,
    'Perovskite_band_gap_graded': per_band_grad,
    'HTL_stack_sequence': htl,
    'Backcontact_stack_sequence': back
})
dp_archi.shape
# Out:
# (27238400, 15)

# %%
# Importing the datapoints which showed improved efficiency from deposition optimization in Step-2
df_imp_pce_depo = pd.read_csv(pwd+"/predictions/improved_pce_depo.csv")
df_imp_pce_depo.shape
# Out:
# (5508977, 30)

# %%
df_imp_pce_depo.head()
# Out:
#   Cell_architecture  Cell_flexible  Cell_semitransparent  \
# 0               pin          False                 False
# 1               pin          False                 False
# 2               pin          False                 False
# 3               pin          False                 False
# 4               pin          False                 False
#
#   Substrate_stack_sequence ETL_stack_sequence  ETL_thickness  \
# 0                SLG | ITO     SnO2-np | CPTA           26.0
# 1                SLG | ITO     SnO2-np | CPTA           26.0
# 2                SLG | ITO     SnO2-np | CPTA           26.0
# 3                SLG | ITO     SnO2-np | CPTA           26.0
# 4                SLG | ITO     SnO2-np | CPTA           26.0
#
#      ETL_deposition_procedure  Perovskite_dimension_2D  \
# 0  Spin-coating | Evaporation                    False
# 1  Spin-coating | Evaporation                    False
# 2  Spin-coating | Evaporation                    False
# 3  Spin-coating | Evaporation                    False
# 4  Spin-coating | Evaporation                    False
#
#    Perovskite_dimension_2D3D_mixture  Perovskite_dimension_3D  ...  \
# 0                              False                     True  ...
# 1                              False                     True  ...
# 2                              False                     True  ...
# 3                              False                     True  ...
# 4                              False                     True  ...
#
#    Perovskite_deposition_thermal_annealing_temperature  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                100
# 4                                                100
#
#    Perovskite_deposition_thermal_annealing_time  \
# 0                                            20
# 1                                            20
# 2                                            20
# 3                                            20
# 4                                            20
#
#   Perovskite_deposition_solvent_annealing  HTL_stack_sequence  \
# 0                                   False               NiO-c
# 1                                   False               NiO-c
# 2                                   False               NiO-c
# 3                                   False               NiO-c
# 4                                   False               NiO-c
#
#    HTL_thickness_list     HTL_deposition_procedure  \
# 0               344.0                 Spin-coating
# 1               344.0                 Spin-coating
# 2               344.0                 Spin-coating
# 3               344.0                 Spin-coating
# 4               344.0  Spin-coating | Spin-coating
#
#    Backcontact_stack_sequence Backcontact_thickness_list  \
# 0                          Cu                      100.0
# 1                          Cu                      100.0
# 2                          Cu                      100.0
# 3                          Cu                      100.0
# 4                          Cu                      100.0
#
#   Backcontact_deposition_procedure  Predicted_PCE
# 0                      Evaporation      13.522444
# 1        Evaporation | Evaporation      13.351723
# 2                      Sandwiching      12.840438
# 3                       Lamination      13.223305
# 4                      Evaporation      13.415419
#
# [5 rows x 30 columns]

# %%
df_imp_pce_depo.sort_values(by="Predicted_PCE",ascending=False,inplace=True) # sorting

# %%
df_imp_pce_depo.head()
# Out:
#         Cell_architecture  Cell_flexible  Cell_semitransparent  \
# 1177441               pin          False                 False
# 993403                pin          False                 False
# 1177201               pin          False                 False
# 993163                pin          False                 False
# 988137                pin          False                 False
#
#         Substrate_stack_sequence ETL_stack_sequence  ETL_thickness  \
# 1177441                SLG | ITO     SnO2-np | CPTA           26.0
# 993403                 SLG | ITO     SnO2-np | CPTA           26.0
# 1177201                SLG | ITO     SnO2-np | CPTA           26.0
# 993163                 SLG | ITO     SnO2-np | CPTA           26.0
# 988137                 SLG | ITO     SnO2-np | CPTA           26.0
#
#           ETL_deposition_procedure  Perovskite_dimension_2D  \
# 1177441  Evaporation | Evaporation                    False
# 993403   Evaporation | Evaporation                    False
# 1177201  Evaporation | Evaporation                    False
# 993163   Evaporation | Evaporation                    False
# 988137   Evaporation | Evaporation                    False
#
#          Perovskite_dimension_2D3D_mixture  Perovskite_dimension_3D  ...  \
# 1177441                              False                     True  ...
# 993403                               False                     True  ...
# 1177201                              False                     True  ...
# 993163                               False                     True  ...
# 988137                               False                     True  ...
#
#          Perovskite_deposition_thermal_annealing_temperature  \
# 1177441                                            60; 100
# 993403                                             60; 100
# 1177201                                            60; 100
# 993163                                             60; 100
# 988137                                         60.0; 100.0
#
#          Perovskite_deposition_thermal_annealing_time  \
# 1177441                                     2.0; 10.0
# 993403                                      2.0; 10.0
# 1177201                                      1.0; 4.0
# 993163                                       1.0; 4.0
# 988137                                      2.0; 10.0
#
#         Perovskite_deposition_solvent_annealing  HTL_stack_sequence  \
# 1177441                                   False               NiO-c
# 993403                                    False               NiO-c
# 1177201                                   False               NiO-c
# 993163                                    False               NiO-c
# 988137                                    False               NiO-c
#
#          HTL_thickness_list     HTL_deposition_procedure  \
# 1177441               344.0  Spin-coating | Spin-coating
# 993403                344.0  Spin-coating | Spin-coating
# 1177201               344.0  Spin-coating | Spin-coating
# 993163                344.0  Spin-coating | Spin-coating
# 988137                344.0  Spin-coating | Spin-coating
#
#          Backcontact_stack_sequence Backcontact_thickness_list  \
# 1177441                          Cu                      100.0
# 993403                           Cu                      100.0
# 1177201                          Cu                      100.0
# 993163                           Cu                      100.0
# 988137                           Cu                      100.0
#
#         Backcontact_deposition_procedure  Predicted_PCE
# 1177441                      Evaporation      15.247782
# 993403                       Evaporation      15.247782
# 1177201                      Evaporation      15.228935
# 993163                       Evaporation      15.228935
# 988137                       Evaporation      15.204399
#
# [5 rows x 30 columns]

# %%
# Taking the most frequent values of thickness and band_gap
for f in ['ETL_thickness', 'Perovskite_thickness','Perovskite_band_gap', 'HTL_thickness_list', 'Backcontact_thickness_list']:
    dp_archi[f] = df[f].mode()[0]

# %%
# All the features related to deposition is replaced with the values with data of highest PCE predicted from Step-2
for f in feats_deposition:
    dp_archi[f] = df_imp_pce_depo[f].iloc[0]

dp_archi = dp_archi[list(feats.columns)]
dp_archi.shape # final shape of the architecture design pool
# Out:
# (27238400, 29)

# %%
dp_archi.head()
# Out:
#   Cell_architecture  Cell_flexible  Cell_semitransparent  \
# 0               pin          False                 False
# 1               pin          False                 False
# 2               pin          False                 False
# 3               pin          False                 False
# 4               pin          False                 False
#
#   Substrate_stack_sequence ETL_stack_sequence  ETL_thickness  \
# 0                SLG | ITO      PCBM-60 | BCP           26.0
# 1                SLG | ITO      PCBM-60 | BCP           26.0
# 2                SLG | ITO      PCBM-60 | BCP           26.0
# 3                SLG | ITO      PCBM-60 | BCP           26.0
# 4                SLG | ITO      PCBM-60 | BCP           26.0
#
#     ETL_deposition_procedure  Perovskite_dimension_2D  \
# 0  Evaporation | Evaporation                     True
# 1  Evaporation | Evaporation                     True
# 2  Evaporation | Evaporation                     True
# 3  Evaporation | Evaporation                     True
# 4  Evaporation | Evaporation                     True
#
#    Perovskite_dimension_2D3D_mixture  Perovskite_dimension_3D  ...  \
# 0                              False                    False  ...
# 1                              False                    False  ...
# 2                              False                    False  ...
# 3                              False                    False  ...
# 4                              False                    False  ...
#
#    Perovskite_deposition_quenching_induced_crystallisation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Perovskite_deposition_thermal_annealing_temperature  \
# 0                                            60; 100
# 1                                            60; 100
# 2                                            60; 100
# 3                                            60; 100
# 4                                            60; 100
#
#   Perovskite_deposition_thermal_annealing_time  \
# 0                                    2.0; 10.0
# 1                                    2.0; 10.0
# 2                                    2.0; 10.0
# 3                                    2.0; 10.0
# 4                                    2.0; 10.0
#
#    Perovskite_deposition_solvent_annealing  HTL_stack_sequence  \
# 0                                    False           PEDOT:PSS
# 1                                    False           PEDOT:PSS
# 2                                    False           PEDOT:PSS
# 3                                    False           PEDOT:PSS
# 4                                    False           PEDOT:PSS
#
#    HTL_thickness_list     HTL_deposition_procedure Backcontact_stack_sequence  \
# 0               344.0  Spin-coating | Spin-coating                         Ag
# 1               344.0  Spin-coating | Spin-coating                         Al
# 2               344.0  Spin-coating | Spin-coating                         Au
# 3               344.0  Spin-coating | Spin-coating                    Ag | Au
# 4               344.0  Spin-coating | Spin-coating                         Cu
#
#   Backcontact_thickness_list  Backcontact_deposition_procedure
# 0                      100.0                       Evaporation
# 1                      100.0                       Evaporation
# 2                      100.0                       Evaporation
# 3                      100.0                       Evaporation
# 4                      100.0                       Evaporation
#
# [5 rows x 29 columns]

# %%
pickle.dump(dp_archi, open(pwd+"/design_pool/design_pool_archi_v2.pkl","wb")) # saving design pool
