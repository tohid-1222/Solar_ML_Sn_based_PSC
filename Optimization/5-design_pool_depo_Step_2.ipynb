# %% [markdown]
# #### Design Pool generation for deposition related features (Step-2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import pickle

# %%
pwd = os.getcwd() # current working directory

# %%
df = pd.read_csv(pwd+"/Sn_based/Sn_cleaned.csv") # Loading cleaned dataset for Sn based perovskites
df.head()
# Out:
#                   Ref_DOI_number Cell_architecture  Cell_flexible  \
# 0         10.1002/adfm.201807696               pin          False
# 1         10.1002/adfm.201807696               pin          False
# 2         10.1002/adfm.201807696               pin          False
# 3         10.1002/adfm.201807696               pin          False
# 4  10.1021/acsenergylett.9b00954               pin          False
#
#    Cell_semitransparent Substrate_stack_sequence ETL_stack_sequence  \
# 0                 False                SLG | ITO      PCBM-60 | BCP
# 1                 False                SLG | ITO      PCBM-60 | BCP
# 2                 False                SLG | ITO      PCBM-60 | BCP
# 3                 False                SLG | ITO      PCBM-60 | BCP
# 4                 False                SLG | ITO          C60 | LiF
#
#    ETL_thickness    ETL_deposition_procedure  Perovskite_dimension_2D  \
# 0          142.0  Spin-coating | Evaporation                     True
# 1          142.0  Spin-coating | Evaporation                     True
# 2          142.0  Spin-coating | Evaporation                     True
# 3          142.0  Spin-coating | Evaporation                     True
# 4           31.0   Evaporation | Evaporation                     True
#
#    Perovskite_dimension_2D3D_mixture  ...  HTL_stack_sequence  \
# 0                              False  ...           PEDOT:PSS
# 1                              False  ...           PEDOT:PSS
# 2                              False  ...           PEDOT:PSS
# 3                              False  ...           PEDOT:PSS
# 4                              False  ...           PEDOT:PSS
#
#    HTL_thickness_list  HTL_deposition_procedure Backcontact_stack_sequence  \
# 0               114.0              Spin-coating                         Ag
# 1               114.0              Spin-coating                         Ag
# 2               114.0              Spin-coating                         Ag
# 3               114.0              Spin-coating                         Ag
# 4                38.0              Spin-coating                         Al
#
#    Backcontact_thickness_list  Backcontact_deposition_procedure  \
# 0                       200.0                       Evaporation
# 1                       200.0                       Evaporation
# 2                       200.0                       Evaporation
# 3                       200.0                       Evaporation
# 4                       100.0                       Evaporation
#
#    JV_default_Voc  JV_default_Jsc JV_default_FF JV_default_PCE
# 0            0.58            21.2         0.633           7.78
# 1            0.60            20.5         0.650           7.95
# 2            0.61            21.0         0.670           8.71
# 3            0.54            20.3         0.630           5.94
# 4            0.56            18.3         0.493           5.07
#
# [5 rows x 34 columns]

# %%
# Selecting columns
cols = ['Cell_architecture', 'Cell_flexible',
       'Cell_semitransparent', 'Substrate_stack_sequence',
       'ETL_stack_sequence', 'ETL_thickness', 'ETL_deposition_procedure',
       'Perovskite_dimension_2D', 'Perovskite_dimension_2D3D_mixture',
       'Perovskite_dimension_3D',
       'Perovskite_dimension_3D_with_2D_capping_layer',
       'Perovskite_composition_perovskite_ABC3_structure',
       'Perovskite_composition_long_form',
       'Perovskite_thickness',
       'Perovskite_composition_inorganic', 'Perovskite_band_gap',
       'Perovskite_band_gap_graded', 'Perovskite_deposition_procedure',
       'Perovskite_deposition_solvents',
       'Perovskite_deposition_quenching_induced_crystallisation',
       'Perovskite_deposition_thermal_annealing_temperature',
       'Perovskite_deposition_thermal_annealing_time',
       'Perovskite_deposition_solvent_annealing', 'HTL_stack_sequence',
       'HTL_thickness_list', 'HTL_deposition_procedure',
       'Backcontact_stack_sequence', 'Backcontact_thickness_list',
       'Backcontact_deposition_procedure', 'JV_default_PCE']
df = df[cols] # selecting the columns which are in the 'cols' list
df.shape
# Out:
# (256, 30)

# %%
feats = df.iloc[:,:-1] # Selecting feature columns
feats.shape # shape of the features
# Out:
# (256, 29)

# %%
# Seperating features into groups of numerical, categorical and boolean types
numerical = list(feats.select_dtypes(include="float64"))
categorical = list(feats.select_dtypes(include="object"))
boolean = list(feats.select_dtypes(include="bool"))

print("Numerical: ", len(numerical))
print("Categorical: ", len(categorical))
print("Boolean: ", len(boolean))
# Out:
# Numerical:  5
# Categorical:  13
# Boolean:  11

# %%
# Features related to device architecture
feats_arch = [        
            'Cell_architecture', 'Cell_flexible',
            'Cell_semitransparent', 'Substrate_stack_sequence',
            'ETL_stack_sequence',
            'ETL_thickness', 
            'Perovskite_dimension_2D', 'Perovskite_dimension_2D3D_mixture',
            'Perovskite_dimension_3D',
            'Perovskite_dimension_3D_with_2D_capping_layer',
            'Perovskite_composition_perovskite_ABC3_structure',
            'Perovskite_composition_long_form',
            'Perovskite_composition_inorganic',
            'Perovskite_thickness',
            'Perovskite_band_gap', 'Perovskite_band_gap_graded',
            'HTL_stack_sequence',
            'HTL_thickness_list',
            'Backcontact_stack_sequence',
            'Backcontact_thickness_list']

# Features related to deposition
feats_deposition = [
            'ETL_deposition_procedure',
            'Perovskite_deposition_procedure', 
            'Perovskite_deposition_solvents',
            'Perovskite_deposition_quenching_induced_crystallisation',
            'Perovskite_deposition_thermal_annealing_temperature',
            'Perovskite_deposition_thermal_annealing_time',
            'Perovskite_deposition_solvent_annealing',
            'HTL_deposition_procedure',
            'Backcontact_deposition_procedure'
]
# printing number of features in each group
print(f"Architecture features: {len(feats_arch)}\nDeposition features: {len(feats_deposition)}\nTotal features: {feats.shape[1]}")
# Out:
# Architecture features: 20
# Deposition features: 9
# Total features: 29

# %%
# Number of unique labels on each feature related to deposition
depo_unique = {}
for f in feats_deposition:
    lst = list(df[f].unique())
    depo_unique[f] = lst
for k in depo_unique.keys():
    print(k+" : "+str(len(depo_unique[k])))
# Out:
# ETL_deposition_procedure : 10
# Perovskite_deposition_procedure : 3
# Perovskite_deposition_solvents : 11
# Perovskite_deposition_quenching_induced_crystallisation : 2
# Perovskite_deposition_thermal_annealing_temperature : 21
# Perovskite_deposition_thermal_annealing_time : 20
# Perovskite_deposition_solvent_annealing : 2
# HTL_deposition_procedure : 5
# Backcontact_deposition_procedure : 4

# %% [markdown]
# ### Design Pool for Deposition related features

# %%
"""
feats_deposition = [
            'ETL_deposition_procedure',
            'Perovskite_deposition_procedure', 
            'Perovskite_deposition_solvents',
            'Perovskite_deposition_quenching_induced_crystallisation',
            'Perovskite_deposition_thermal_annealing_temperature',
            'Perovskite_deposition_thermal_annealing_time',
            'Perovskite_deposition_solvent_annealing',
            'HTL_deposition_procedure',
            'Backcontact_deposition_procedure'
]
"""
# Making a list of unique labels in each column
etl_depo_lst = depo_unique["ETL_deposition_procedure"]
per_depo_lst = depo_unique["Perovskite_deposition_procedure"]
per_sol_lst = depo_unique["Perovskite_deposition_solvents"]
per_qic_lst = depo_unique["Perovskite_deposition_quenching_induced_crystallisation"]
per_temp_lst = depo_unique["Perovskite_deposition_thermal_annealing_temperature"]
per_time_lst = depo_unique["Perovskite_deposition_thermal_annealing_time"]
per_ann_lst = depo_unique["Perovskite_deposition_solvent_annealing"]
htl_depo_lst = depo_unique["HTL_deposition_procedure"]
back_depo_lst = depo_unique["Backcontact_deposition_procedure"]

etl_depo = []
per_depo = []
per_sol = []
per_qic = []
per_temp = []
per_time = []
per_ann = []
htl_depo = []
back_depo = []

# Permutating through each layers of features
for l0 in etl_depo_lst:
    for l1 in per_depo_lst:
        for l2 in per_sol_lst:
            for l3 in per_qic_lst:
                for l4 in per_temp_lst:
                    for l5 in per_time_lst:
                        for l6 in per_ann_lst:
                            for l7 in htl_depo_lst:
                                for l8 in back_depo_lst:
                                    etl_depo.append(l0)
                                    per_depo.append(l1)
                                    per_sol.append(l2)
                                    per_qic.append(l3)
                                    per_temp.append(l4)
                                    per_time.append(l5)
                                    per_ann.append(l6)
                                    htl_depo.append(l7)
                                    back_depo.append(l8)

# Create a design pool of all possible combination of deposition related features   
dp_depo = pd.DataFrame(
        {
            'ETL_deposition_procedure': etl_depo,
            'Perovskite_deposition_procedure': per_depo,
            'Perovskite_deposition_solvents': per_sol, 
            'Perovskite_deposition_quenching_induced_crystallisation': per_qic,
            'Perovskite_deposition_thermal_annealing_temperature': per_temp,
            'Perovskite_deposition_thermal_annealing_time': per_time,
            'Perovskite_deposition_solvent_annealing': per_ann,
            'HTL_deposition_procedure': htl_depo,
            'Backcontact_deposition_procedure': back_depo
        }
    )

dp_depo.shape # Initial shape of the design pool
# Out:
# (11088000, 9)

# %%
dp_depo.head()
# Out:
#      ETL_deposition_procedure Perovskite_deposition_procedure  \
# 0  Spin-coating | Evaporation                    Spin-coating
# 1  Spin-coating | Evaporation                    Spin-coating
# 2  Spin-coating | Evaporation                    Spin-coating
# 3  Spin-coating | Evaporation                    Spin-coating
# 4  Spin-coating | Evaporation                    Spin-coating
#
#   Perovskite_deposition_solvents  \
# 0                      DMF; DMSO
# 1                      DMF; DMSO
# 2                      DMF; DMSO
# 3                      DMF; DMSO
# 4                      DMF; DMSO
#
#    Perovskite_deposition_quenching_induced_crystallisation  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Perovskite_deposition_thermal_annealing_temperature  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                100
# 4                                                100
#
#   Perovskite_deposition_thermal_annealing_time  \
# 0                                           20
# 1                                           20
# 2                                           20
# 3                                           20
# 4                                           20
#
#    Perovskite_deposition_solvent_annealing     HTL_deposition_procedure  \
# 0                                    False                 Spin-coating
# 1                                    False                 Spin-coating
# 2                                    False                 Spin-coating
# 3                                    False                 Spin-coating
# 4                                    False  Spin-coating | Spin-coating
#
#   Backcontact_deposition_procedure
# 0                      Evaporation
# 1        Evaporation | Evaporation
# 2                      Sandwiching
# 3                       Lamination
# 4                      Evaporation

# %%
# Importing the datapoints which showed improved efficiency from architecture optimization in Step-1
df_imp_pce_arch = pd.read_csv(pwd+"/predictions/improved_pce_archi.csv") # Reading the improved pce data
df_imp_pce_arch.shape
# Out:
# (11834, 30)

# %%
df_imp_pce_arch.head()
# Out:
#   Cell_architecture  Cell_flexible  Cell_semitransparent  \
# 0               pin          False                 False
# 1               pin          False                 False
# 2               pin          False                 False
# 3               pin          False                 False
# 4               pin          False                 False
#
#   Substrate_stack_sequence ETL_stack_sequence  ETL_thickness  \
# 0                SLG | ITO      PCBM-60 | BCP           26.0
# 1                SLG | ITO      PCBM-60 | BCP           26.0
# 2                SLG | ITO      PCBM-60 | BCP           26.0
# 3                SLG | ITO      PCBM-60 | BCP           26.0
# 4                SLG | ITO      PCBM-60 | BCP           26.0
#
#     ETL_deposition_procedure  Perovskite_dimension_2D  \
# 0  Evaporation | Evaporation                    False
# 1  Evaporation | Evaporation                    False
# 2  Evaporation | Evaporation                    False
# 3  Evaporation | Evaporation                    False
# 4  Evaporation | Evaporation                    False
#
#    Perovskite_dimension_2D3D_mixture  Perovskite_dimension_3D  ...  \
# 0                              False                     True  ...
# 1                              False                     True  ...
# 2                              False                     True  ...
# 3                              False                     True  ...
# 4                              False                     True  ...
#
#    Perovskite_deposition_thermal_annealing_temperature  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                100
# 4                                                100
#
#    Perovskite_deposition_thermal_annealing_time  \
# 0                                            10
# 1                                            10
# 2                                            10
# 3                                            10
# 4                                            10
#
#   Perovskite_deposition_solvent_annealing  HTL_stack_sequence  \
# 0                                   False           PEDOT:PSS
# 1                                   False             PCBM-60
# 2                                   False               NiO-c
# 3                                   False              NiO-np
# 4                                   False                PTAA
#
#    HTL_thickness_list  HTL_deposition_procedure  Backcontact_stack_sequence  \
# 0               344.0              Spin-coating                          Cu
# 1               344.0              Spin-coating                          Cu
# 2               344.0              Spin-coating                          Cu
# 3               344.0              Spin-coating                          Cu
# 4               344.0              Spin-coating                          Cu
#
#   Backcontact_thickness_list Backcontact_deposition_procedure  Predicted_PCE
# 0                      100.0                      Evaporation      12.442712
# 1                      100.0                      Evaporation      12.442712
# 2                      100.0                      Evaporation      12.600066
# 3                      100.0                      Evaporation      12.251941
# 4                      100.0                      Evaporation      12.338658
#
# [5 rows x 30 columns]

# %%
df_imp_pce_arch.sort_values(by="Predicted_PCE",ascending=False,inplace=True) # Sorting data based on Predicted PCE

# %%
df_imp_pce_arch.head()
# Out:
#      Cell_architecture  Cell_flexible  Cell_semitransparent  \
# 2450               pin          False                 False
# 822                pin          False                 False
# 4596               pin          False                 False
# 4335               pin          False                 False
# 4679               pin          False                 False
#
#      Substrate_stack_sequence   ETL_stack_sequence  ETL_thickness  \
# 2450                SLG | ITO       SnO2-np | CPTA           26.0
# 822                 SLG | ITO  PCBM-60 | C60 | BCP           26.0
# 4596                SLG | FTO  PCBM-60 | C60 | BCP           26.0
# 4335                SLG | FTO  PCBM-60 | C60 | BCP           26.0
# 4679                SLG | FTO  PCBM-60 | C60 | BCP           26.0
#
#        ETL_deposition_procedure  Perovskite_dimension_2D  \
# 2450  Evaporation | Evaporation                    False
# 822   Evaporation | Evaporation                    False
# 4596  Evaporation | Evaporation                    False
# 4335  Evaporation | Evaporation                    False
# 4679  Evaporation | Evaporation                    False
#
#       Perovskite_dimension_2D3D_mixture  Perovskite_dimension_3D  ...  \
# 2450                              False                     True  ...
# 822                               False                     True  ...
# 4596                              False                     True  ...
# 4335                              False                     True  ...
# 4679                              False                     True  ...
#
#       Perovskite_deposition_thermal_annealing_temperature  \
# 2450                                                100
# 822                                                 100
# 4596                                                100
# 4335                                                100
# 4679                                                100
#
#       Perovskite_deposition_thermal_annealing_time  \
# 2450                                            10
# 822                                             10
# 4596                                            10
# 4335                                            10
# 4679                                            10
#
#      Perovskite_deposition_solvent_annealing  HTL_stack_sequence  \
# 2450                                   False               NiO-c
# 822                                    False              NiO-np
# 4596                                   False        Spiro-MeOTAD
# 4335                                   False        Spiro-MeOTAD
# 4679                                   False        Spiro-MeOTAD
#
#       HTL_thickness_list  HTL_deposition_procedure  \
# 2450               344.0              Spin-coating
# 822                344.0              Spin-coating
# 4596               344.0              Spin-coating
# 4335               344.0              Spin-coating
# 4679               344.0              Spin-coating
#
#       Backcontact_stack_sequence Backcontact_thickness_list  \
# 2450                          Cu                      100.0
# 822                           Cu                      100.0
# 4596                          Cu                      100.0
# 4335                          Cu                      100.0
# 4679                          Cu                      100.0
#
#      Backcontact_deposition_procedure  Predicted_PCE
# 2450                      Evaporation      13.569096
# 822                       Evaporation      13.523774
# 4596                      Evaporation      13.506297
# 4335                      Evaporation      13.506297
# 4679                      Evaporation      13.506297
#
# [5 rows x 30 columns]

# %%
# All the features related to architecture is replaced with the values with data of highest PCE predicted from Step-1
for f in feats_arch:
    dp_depo[f] = df_imp_pce_arch[f].iloc[0]
dp_depo = dp_depo[list(feats.columns)]
dp_depo.shape # final shape of the Deposition design pool
# Out:
# (11088000, 29)

# %%
dp_depo.head()
# Out:
#   Cell_architecture  Cell_flexible  Cell_semitransparent  \
# 0               pin          False                 False
# 1               pin          False                 False
# 2               pin          False                 False
# 3               pin          False                 False
# 4               pin          False                 False
#
#   Substrate_stack_sequence ETL_stack_sequence  ETL_thickness  \
# 0                SLG | ITO     SnO2-np | CPTA           26.0
# 1                SLG | ITO     SnO2-np | CPTA           26.0
# 2                SLG | ITO     SnO2-np | CPTA           26.0
# 3                SLG | ITO     SnO2-np | CPTA           26.0
# 4                SLG | ITO     SnO2-np | CPTA           26.0
#
#      ETL_deposition_procedure  Perovskite_dimension_2D  \
# 0  Spin-coating | Evaporation                    False
# 1  Spin-coating | Evaporation                    False
# 2  Spin-coating | Evaporation                    False
# 3  Spin-coating | Evaporation                    False
# 4  Spin-coating | Evaporation                    False
#
#    Perovskite_dimension_2D3D_mixture  Perovskite_dimension_3D  ...  \
# 0                              False                     True  ...
# 1                              False                     True  ...
# 2                              False                     True  ...
# 3                              False                     True  ...
# 4                              False                     True  ...
#
#    Perovskite_deposition_quenching_induced_crystallisation  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    Perovskite_deposition_thermal_annealing_temperature  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                100
# 4                                                100
#
#   Perovskite_deposition_thermal_annealing_time  \
# 0                                           20
# 1                                           20
# 2                                           20
# 3                                           20
# 4                                           20
#
#    Perovskite_deposition_solvent_annealing  HTL_stack_sequence  \
# 0                                    False               NiO-c
# 1                                    False               NiO-c
# 2                                    False               NiO-c
# 3                                    False               NiO-c
# 4                                    False               NiO-c
#
#    HTL_thickness_list     HTL_deposition_procedure Backcontact_stack_sequence  \
# 0               344.0                 Spin-coating                         Cu
# 1               344.0                 Spin-coating                         Cu
# 2               344.0                 Spin-coating                         Cu
# 3               344.0                 Spin-coating                         Cu
# 4               344.0  Spin-coating | Spin-coating                         Cu
#
#   Backcontact_thickness_list  Backcontact_deposition_procedure
# 0                      100.0                       Evaporation
# 1                      100.0         Evaporation | Evaporation
# 2                      100.0                       Sandwiching
# 3                      100.0                        Lamination
# 4                      100.0                       Evaporation
#
# [5 rows x 29 columns]

# %%
pickle.dump(dp_depo, open(pwd+"/design_pool/design_pool_depo.pkl","wb")) # Saving the design pool
